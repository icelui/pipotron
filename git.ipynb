# %%
from google.colab import drive
drive.mount('/drive')
# %cd /drive/MyDrive/data/pipotron
# %ls -al
# Out:
# Mounted at /drive
# /drive/MyDrive/data/pipotron
# total 70
# drwx------ 2 root root  4096 Mar 16 10:48 donnees/
# drwx------ 2 root root  4096 Mar 16 10:40 .git/
# -rw------- 1 root root  1819 Mar 16 11:10 .gitignore
# -rw------- 1 root root  4451 Mar 16 12:39 git.ipynb
# drwx------ 2 root root  4096 Mar 16 10:46 models/
# -rw------- 1 root root 51694 Mar 17 09:50 pipotron_entrainement.ipynb
# -rw------- 1 root root    79 Mar 16 10:40 README.md

# %%
# !git config --global user.name Francois-Guerillon
# !git config --global user.email git@fguerillon.net
# !git config --global user.name

from getpass import getpass
github_username = 'icelui'
github_password = getpass('Mot de passe GitHub :')
# Out:
# Francois-Guerillon
# Mot de passe GitHub :··········

# %%
# !git add *.ipynb
# !git add donnees/*

# !git commit -m "Suppression des doublons"
# Out:
# [main aa22883] Suppression des doublons
#  3 files changed, 2 insertions(+), 462 deletions(-)
#  rewrite pipotron_entrainement.ipynb (89%)

# %%
# !git push
# Out:
# Counting objects: 6, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (6/6), 6.15 KiB | 1.02 MiB/s, done.
# Total 6 (delta 3), reused 0 (delta 0)
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/icelui/pipotron.git
#    9f2d640..aa22883  main -> main
